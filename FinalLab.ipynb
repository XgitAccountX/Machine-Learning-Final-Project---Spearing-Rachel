# %% [markdown]
# <a href="https://colab.research.google.com/github/XgitAccountX/Machine-Learning-Final-Project---Spearing-Rachel/blob/main/FinalLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import seaborn as sns


from sklearn import preprocessing
from google.colab import files
files.upload()


# !ls


'''https://catalog.data.gov/dataset/mypyramid-food-raw-data#sec-dates
Publisher Food and Nutrition SErvice, DEpertmen of Agriculture
Maintiner Angela Leone
Metad ata created Date November 10,2020
Metadat updated data November 13, 2020

My Pyramida Food Raw Data

Food and Nutrotion Service DNS USDa
'''



#Predict Calories based of Portion Amount, Type, display_name, and saturated fats.
 
df2 = pd.read_excel('./Food_Display_Table.xlsx')
df = df2.copy()



#drop null values.
df = df.dropna();

print(df.describe())


sns.set(rc={'figure.figsize':(20,10)})


#this graph shows the calories of each increasing portion amount of each ite,
#sns.lineplot(data=df, x=df['Portion_Amount'], y = df['Calories'], hue=df['Display_Name'] )

#doesn't workj well
#sns.barplot(data=df, x=df['Portion_Amount'], y = df['Calories'], hue=df['Display_Name'] )

#a great graph showing the relationship between saturated fats and calories, for each portion size. 
#sns.pairplot(df, x_vars='Saturated_Fats' , y_vars='Calories', hue='Portion_Display_Name')


#sns.pairplot(df, x_vars='Food_Code' , y_vars='Calories', hue='Display_Name')

#sns.pairplot(df, x_vars='Portion_Default' , y_vars='Calories', hue='Display_Name')


#sns.pairplot(df, x_vars='Grains' , y_vars='Calories', hue='Display_Name')

#sns.pairplot(df, x_vars='Vegetables' , y_vars='Calories', hue='Display_Name')

#amazing plot below
#sns.pairplot(df, x_vars='Vegetables' , y_vars='Saturated_Fats', hue='Calories')


#food graph
#sns.lmplot(x="Calories", y='Saturated_Fats', hue='Display_Name', data=df)

#df = df.sort_values(by='Calories', axis=0)


#the mean price for a cup of something.
#sns.lineplot(data=df, ). mean("count")

#to get rid of duplicate rows, where 1 cup of Kix cereal, versus  a single serving box of ceereal


#sns.lineplot(data=df, x=df['Portion_Amount'], y = df['Calories'], hue=df['Display_Name'] )


#print(df.loc[ ( df['Portion_Display_Name']=='cup') ]['Calories']].transform("mean") )


#df.groupby('Calories').transform('mean')


#sns.lineplot(data=df, x=df['Portion_Amount'], y = df.groupby('Calories').transform('mean') , hue=df['Display_Name'] )

#sns.scatterplot(data=df, x=df['Calories'], y = df['Saturated_Fats'])

#sns.scatterplot(data=df, x=df['Calories'], y = df['Milk'])

#the average calories by saturated fats content
#the x, is portion size
#the y is the average calories for portion size.
#the hue is the type
#sns.scatterplot(data=df, x=df['Calories'], y = df['Grains'])



#sns.lineplot(data=df, x=df['Portion_Amount'], y = df.groupby('Portion_am')['Saturated_Fats'].transform('mean') , hue=df['Display_Name'] )


#this might be aggregate.
#sns.scatterplot(data=df, x=df.groupby('Portion_Amount')['Calories'].transform('mean'), y = df['Portion_Amount'])

#this is nice
sns.scatterplot(data=df, x=df.groupby('Display_Name')['Calories'].transform('mean'), y = df.loc[ (df['Portion_Display_Name']=='cup') ]['Portion_Amount'])



df
# Out:
#      <input type="file" id="files-172255a2-f13d-4c3d-8158-1d887552504c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-172255a2-f13d-4c3d-8158-1d887552504c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Food_Display_Table.xlsx to Food_Display_Table (34).xlsx
# 'Food_Display_Table (10).xlsx'	'Food_Display_Table (27).xlsx'
# 'Food_Display_Table (11).xlsx'	'Food_Display_Table (28).xlsx'
# 'Food_Display_Table (12).xlsx'	'Food_Display_Table (29).xlsx'
# 'Food_Display_Table (13).xlsx'	'Food_Display_Table (2).xlsx'
# 'Food_Display_Table (14).xlsx'	'Food_Display_Table (30).xlsx'
# 'Food_Display_Table (15).xlsx'	'Food_Display_Table (31).xlsx'
# 'Food_Display_Table (16).xlsx'	'Food_Display_Table (32).xlsx'
# 'Food_Display_Table (17).xlsx'	'Food_Display_Table (33).xlsx'
# 'Food_Display_Table (18).xlsx'	'Food_Display_Table (34).xlsx'
# 'Food_Display_Table (19).xlsx'	'Food_Display_Table (3).xlsx'
# 'Food_Display_Table (1).xlsx'	'Food_Display_Table (4).xlsx'
# 'Food_Display_Table (20).xlsx'	'Food_Display_Table (5).xlsx'
# 'Food_Display_Table (21).xlsx'	'Food_Display_Table (6).xlsx'
# 'Food_Display_Table (22).xlsx'	'Food_Display_Table (7).xlsx'
# 'Food_Display_Table (23).xlsx'	'Food_Display_Table (8).xlsx'
# 'Food_Display_Table (24).xlsx'	'Food_Display_Table (9).xlsx'
# 'Food_Display_Table (25).xlsx'	 Food_Display_Table.xlsx
# 'Food_Display_Table (26).xlsx'	 sample_data
#           Food_Code  Portion_Default  Portion_Amount       Factor  \
# count  2.011000e+03      2011.000000     2011.000000  2011.000000
# mean   5.291130e+07         1.496768        1.194058     1.132641
# std    2.452322e+07         0.500114        1.441277     1.319820
# min    7.258000e+03         1.000000        0.250000     0.060000
# 25%    2.721410e+07         1.000000        1.000000     1.000000
# 50%    5.440307e+07         1.000000        1.000000     1.000000
# 75%    7.225201e+07         2.000000        1.000000     1.000000
# max    9.421010e+07         2.000000       20.000000    20.000000
#
#          Increment   Multiplier       Grains  Whole_Grains   Vegetables  \
# count  2011.000000  2011.000000  2011.000000   2011.000000  2011.000000
# mean      0.559423     0.575584     0.505209      0.048116     0.105412
# std       0.417079     0.257651     0.958691      0.271888     0.241705
# min       0.250000     0.100000     0.000000      0.000000     0.000000
# 25%       0.250000     0.500000     0.000000      0.000000     0.000000
# 50%       0.500000     0.500000     0.000000      0.000000     0.000000
# 75%       0.500000     0.500000     0.687470      0.000000     0.038365
# max       5.000000     1.000000     8.291140      5.038260     3.444000
#
#        Orange_Vegetables  ...         Milk        Meats          Soy  \
# count        2011.000000  ...  2011.000000  2011.000000  2011.000000
# mean            0.007403  ...     0.084292     0.639947     0.013827
# std             0.056005  ...     0.244927     1.245227     0.140962
# min             0.000000  ...     0.000000     0.000000     0.000000
# 25%             0.000000  ...     0.000000     0.000000     0.000000
# 50%             0.000000  ...     0.000000     0.000000     0.000000
# 75%             0.000000  ...     0.000000     0.734140     0.000000
# max             1.000640  ...     2.605680    10.657800     2.504170
#
#        Drybeans_Peas         Oils   Solid_Fats  Added_Sugars      Alcohol  \
# count    2011.000000  2011.000000  2011.000000   2011.000000  2011.000000
# mean        0.006031     0.298964    32.351489     15.785424     2.829184
# std         0.049676     0.855512    59.726893     40.914788    21.568194
# min         0.000000     0.000000     0.000000      0.000000     0.000000
# 25%         0.000000     0.000000     0.000000      0.000000     0.000000
# 50%         0.000000     0.000000     5.119200      0.000000     0.000000
# 75%         0.000000     0.037050    41.460480     10.334740     0.000000
# max         0.612900    12.111110   719.607780    569.818430   325.369800
#
#           Calories  Saturated_Fats
# count  2011.000000     2011.000000
# mean    154.508876        2.136432
# std     146.108102        3.301416
# min       0.000000        0.000000
# 25%      53.475000        0.082500
# 50%     115.920000        0.865000
# 75%     208.920000        2.856600
# max    1667.400000       36.786600
#
# [8 rows x 24 columns]
#       Food_Code                      Display_Name  Portion_Default  \
# 0      12350000                    Sour cream dip                1
# 1      13110100                Ice cream, regular                1
# 2      13110120                   Ice cream, rich                1
# 3      13110200              Soft serve ice cream                1
# 4      13120100  Ice cream bar, chocolate covered                1
# ...         ...                               ...              ...
# 2009   57301500                     Kashi, puffed                1
# 2010   57303100                        Kix cereal                1
# 2011   57303100                        Kix cereal                2
# 2012   57304100    Life cereal (plain & cinnamon)                1
# 2013   57305100               Lucky Charms cereal                1
#
#       Portion_Amount Portion_Display_Name  Factor  Increment  Multiplier  \
# 0               0.25                  cup    0.25       0.25        1.00
# 1               1.00                  cup    1.00       0.25        0.25
# 2               1.00                  cup    1.00       0.25        0.25
# 3               1.00                  cup    1.00       0.25        0.25
# 4               1.00  bar (bar = 3 fl oz)    1.00       0.50        0.50
# ...              ...                  ...     ...        ...         ...
# 2009            1.00                  cup    1.00       0.25        0.25
# 2010            1.00                  cup    1.00       0.25        0.25
# 2011            1.00   single serving box    1.00       0.50        0.50
# 2012            1.00                  cup    1.00       0.25        0.25
# 2013            1.00                  cup    1.00       0.25        0.25
#
#        Grains  Whole_Grains  ...     Milk   Meats  Soy  Drybeans_Peas  \
# 0     0.04799       0.00000  ...  0.00000  0.0000  0.0            0.0
# 1     0.00000       0.00000  ...  0.29393  0.0000  0.0            0.0
# 2     0.00000       0.00000  ...  0.25160  0.0962  0.0            0.0
# 3     0.00000       0.00000  ...  0.38233  0.0000  0.0            0.0
# 4     0.00000       0.00000  ...  0.09744  0.0000  0.0            0.0
# ...       ...           ...  ...      ...     ...  ...            ...
# 2009  0.84672       0.84672  ...  0.00000  0.0000  0.0            0.0
# 2010  0.67804       0.23782  ...  0.00000  0.0000  0.0            0.0
# 2011  0.55476       0.19458  ...  0.00000  0.0000  0.0            0.0
# 2012  1.24652       0.80124  ...  0.00000  0.0000  0.0            0.0
# 2013  0.58290       0.50790  ...  0.00000  0.0000  0.0            0.0
#
#          Oils  Solid_Fats  Added_Sugars  Alcohol  Calories  Saturated_Fats
# 0     0.00000   105.64850       1.57001      0.0    133.65         7.36898
# 1     0.00000   130.99968      95.20488      0.0    267.33         9.03070
# 2     0.00000   213.06672      96.10340      0.0    368.52        15.28840
# 3     0.00000   170.39808     123.83793      0.0    347.73        11.74670
# 4     0.00000   112.32144      45.54761      0.0    169.12         9.58720
# ...       ...         ...           ...      ...       ...             ...
# 2009  0.00005     0.00000       0.00000      0.0     87.60         0.07920
# 2010  0.00000     0.00000       8.93255      0.0     82.94         0.11000
# 2011  0.00000     0.00000       7.30845      0.0     67.86         0.09000
# 2012  0.00000     0.00000      32.09710      0.0    165.00         0.35640
# 2013  0.00287     0.00000      49.57145      0.0    114.00         0.24000
#
# [2011 rows x 26 columns]
