# %% [markdown]
# <a href="https://colab.research.google.com/github/XgitAccountX/Machine-Learning-Final-Project---Spearing-Rachel/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import seaborn as sns

from sklearn import preprocessing
from google.colab import files
import matplotlib.pyplot as plt

files.upload()


# !ls
df2 = pd.read_csv('./Vegetables_Pulses2021.csv').copy()
df = df2.copy()

#drop null values.
df = df.dropna();

print(df['PublishValue'].describe())
print(df.describe())


#df = df.sort_values(by='Year', axis=0)
#df.groupby(by='Year')
#sns.set(rc={'figure.figsize':(36, 22)})
#first graph
#sns.lineplot(data=df, x=df['Year'], y=df['PublishValue'], hue=df['Commodity']  )

#third graph
#sns.pairplot(df, x_vars=df.loc[(df['Commodity'] =='Asparagus')], y_vars='Year' )

#second graph
#df = df.sort_values(by='Unit', axis=0)
#df.groupby(by='Unit')
#sns.lineplot(data=df, x=df['PublishValue'], y=df['Year'], hue=df['Unit']  )





#df
# Out:
#      <input type="file" id="files-2c0c3e25-42d9-418f-b9ad-be6196771479" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c0c3e25-42d9-418f-b9ad-be6196771479">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vegetables_Pulses2021.csv to Vegetables_Pulses2021 (7).csv
#  sample_data			 'Vegetables_Pulses2021 (5).csv'
# 'Vegetables_Pulses2021 (1).csv'  'Vegetables_Pulses2021 (6).csv'
# 'Vegetables_Pulses2021 (2).csv'  'Vegetables_Pulses2021 (7).csv'
# 'Vegetables_Pulses2021 (3).csv'   Vegetables_Pulses2021.csv
# 'Vegetables_Pulses2021 (4).csv'
# count     37176
# unique    17927
# top           0
# freq        346
# Name: PublishValue, dtype: object
#         Decade   Year  Commodity    EndUse Category        Item  \
# ...
